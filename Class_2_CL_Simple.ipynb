# %% [markdown]
# The SimCLR approach aims to learn meaningful representations of images in a self-supervised manner. It does this by maximizing the cosine similarity between representations of augmented views of the same image (positive pairs) and minimizing the cosine similarity between representations of different images (negative pairs). The contrastive loss encourages the encoder to learn representations that are invariant to the applied data augmentations.
#
# The visualization using t-SNE allows us to assess the quality of the learned representations by observing how well the different classes are separated in the low-dimensional space.

# %% [markdown]
# This code demonstrates the implementation of a self-supervised learning approach called SimCLR (Simple Framework for Contrastive Learning of Visual Representations) using the CIFAR-10 dataset. Let's go through the code section by section:
#
# 1. Importing Libraries:
#    - The necessary libraries, including TensorFlow, Keras, Matplotlib, and scikit-learn, are imported.
#
# 2. Loading and Preprocessing Data:
#    - The CIFAR-10 dataset is loaded using `keras.datasets.cifar10.load_data()`.
#    - The pixel values of the training and testing data are normalized to the range [0, 1].
#    - The training data is converted into a TensorFlow Dataset using `tf.data.Dataset.from_tensor_slices()` and batched.
#
# 3. Data Augmentation:
#    - A data augmentation pipeline is defined using `keras.Sequential()` to apply random cropping, flipping, rescaling, and zooming to the input images.
#
# 4. Defining the Encoder Network:
#    - The `create_encoder` function defines the base encoder network using convolutional layers, max pooling, and a global max pooling layer.
#    - The encoder network takes an input image and outputs a 128-dimensional feature representation.
#
# 5. Defining the Projection Head:
#    - The `create_projection_head` function defines the projection head network using dense layers.
#    - The projection head takes the 128-dimensional feature representation from the encoder and projects it to a 128-dimensional space.
#
# 6. Training Loop:
#    - The training loop runs for a specified number of epochs.
#    - For each batch of training data:
#      - The encoder and projection head are applied to the batch of images.
#      - The resulting projected representations are L2-normalized.
#      - The cosine similarity matrix is computed between the normalized representations.
#      - The contrastive loss is calculated using the cosine similarity matrix and temperature scaling.
#      - The gradients of the loss with respect to the weights of the encoder and projection head are computed.
#      - The optimizer is used to update the weights of the encoder and projection head.
#
# 7. Extracting Representations:
#    - After training, the trained encoder is used to extract representations (embeddings) for the test images.
#
# 8. t-SNE Visualization:
#    - The t-SNE algorithm is used to reduce the dimensionality of the learned representations to 2D.
#    - The t-SNE results are plotted using Matplotlib, with each point colored according to its true class label.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Load and preprocess the CIFAR-10 dataset
(x_train, _), (x_test, y_test) = keras.datasets.cifar10.load_data()
x_train, x_test = x_train.astype('float32') / 255.0, x_test.astype('float32') / 255.0

batch_size = 256

# Convert the training data into a TensorFlow Dataset
train_dataset = tf.data.Dataset.from_tensor_slices(x_train).batch(batch_size)

# Define the data augmentation function
data_augmentation = keras.Sequential([
    layers.RandomCrop(height=32, width=32),
    layers.RandomFlip("horizontal"),
    layers.Rescaling(1./255),
    layers.RandomZoom(0.2),
])

# Define the base encoder network
def create_encoder():
    inputs = layers.Input(shape=(32, 32, 3))
    x = data_augmentation(inputs)
    x = layers.Conv2D(32, 3, activation='relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(64, 3, activation='relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(128, 3, activation='relu')(x)
    x = layers.GlobalMaxPooling2D()(x)
    outputs = layers.Dense(128)(x)
    return keras.Model(inputs=inputs, outputs=outputs)

# Define the projection head
def create_projection_head():
    inputs = keras.Input(shape=(128,))
    x = layers.Dense(256, activation='relu')(inputs)
    outputs = layers.Dense(128)(x)
    return keras.Model(inputs=inputs, outputs=outputs)

encoder = create_encoder()
projection_head = create_projection_head()

optimizer = keras.optimizers.Adam()
batch_size = 256
epochs = 100
temperature = 0.1

# Custom training loop
for epoch in range(epochs):
    print(f"\nStart of epoch {epoch}")
    for step, x_batch_train in enumerate(train_dataset):
        with tf.GradientTape() as tape:
            # Forward pass
            encoded = encoder(x_batch_train, training=True)
            projected = projection_head(encoded, training=True)
            normalized = tf.math.l2_normalize(projected, axis=1)
            cosine_similarity = tf.matmul(normalized, normalized, transpose_b=True)
            logits = cosine_similarity / temperature
            labels = tf.range(x_batch_train.shape[0])
            loss_value = keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
            loss_value = tf.reduce_mean(loss_value)

        # Get gradients of loss wrt the weights.
        gradients = tape.gradient(loss_value, encoder.trainable_weights + projection_head.trainable_weights)

        # Update the weights of the encoder and projection head.
        optimizer.apply_gradients(zip(gradients, encoder.trainable_weights + projection_head.trainable_weights))

        if step % 100 == 0:
            print(f"Training loss (for one batch) at step {step}: {float(loss_value)}")

# Extract representations after training
representations = encoder.predict(x_test)

# t-SNE visualization
tsne = TSNE(n_components=2, perplexity=30, n_iter=3000)
tsne_results = tsne.fit_transform(representations)

plt.figure(figsize=(8, 8))
plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=y_test.flatten(), cmap='rainbow')
plt.title('t-SNE Visualization of Learned Representations')
plt.colorbar()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 1634s 10us/step
#
# Start of epoch 0
# Training loss (for one batch) at step 0: 5.212796688079834
# Training loss (for one batch) at step 100: 5.544126987457275
#
# Start of epoch 1
# Training loss (for one batch) at step 0: 4.540711402893066
# Training loss (for one batch) at step 100: 1.7534505128860474
#
# Start of epoch 2
# Training loss (for one batch) at step 0: 0.5544741153717041
# Training loss (for one batch) at step 100: 0.21109209954738617
#
# Start of epoch 3
# Training loss (for one batch) at step 0: 0.15789714455604553
# Training loss (for one batch) at step 100: 0.09657466411590576
#
# Start of epoch 4
# Training loss (for one batch) at step 0: 0.07779212296009064
# Training loss (for one batch) at step 100: 0.08635508269071579
#
# Start of epoch 5
# Training loss (for one batch) at step 0: 0.055492691695690155
# Training loss (for one batch) at step 100: 0.07215721905231476
#
# Start of epoch 6
# Training loss (for one batch) at step 0: 0.058071430772542953
# Training loss (for one batch) at step 100: 0.0515456423163414
#
# Start of epoch 7
# Training loss (for one batch) at step 0: 0.04716593399643898
# Training loss (for one batch) at step 100: 0.045222096145153046
#
# Start of epoch 8
# Training loss (for one batch) at step 0: 0.03806627541780472
# Training loss (for one batch) at step 100: 0.037641484290361404
#
# Start of epoch 9
# Training loss (for one batch) at step 0: 0.03991251066327095
# Training loss (for one batch) at step 100: 0.037139445543289185
#
# Start of epoch 10
# Training loss (for one batch) at step 0: 0.035740479826927185
# Training loss (for one batch) at step 100: 0.03513682261109352
#
# Start of epoch 11
# Training loss (for one batch) at step 0: 0.03365166112780571
# Training loss (for one batch) at step 100: 0.032923296093940735
#
# Start of epoch 12
# Training loss (for one batch) at step 0: 0.03359903395175934
# Training loss (for one batch) at step 100: 0.03260628134012222
#
# Start of epoch 13
# Training loss (for one batch) at step 0: 0.030843574553728104
# Training loss (for one batch) at step 100: 0.02974998950958252
#
# Start of epoch 14
# Training loss (for one batch) at step 0: 0.028817933052778244
# Training loss (for one batch) at step 100: 0.028595104813575745
#
# Start of epoch 15
# Training loss (for one batch) at step 0: 0.028778716921806335
# Training loss (for one batch) at step 100: 0.02955736592411995
#
# Start of epoch 16
# Training loss (for one batch) at step 0: 0.029794905334711075
# Training loss (for one batch) at step 100: 0.027031630277633667
#
# Start of epoch 17
# Training loss (for one batch) at step 0: 0.027566857635974884
# Training loss (for one batch) at step 100: 0.028179248794913292
#
# Start of epoch 18
# Training loss (for one batch) at step 0: 0.02580716460943222
# Training loss (for one batch) at step 100: 0.025690365582704544
#
# Start of epoch 19
# Training loss (for one batch) at step 0: 0.02376752719283104
# Training loss (for one batch) at step 100: 0.028121670708060265
#
# Start of epoch 20
# Training loss (for one batch) at step 0: 0.0261896513402462
# Training loss (for one batch) at step 100: 0.024700913578271866
#
# Start of epoch 21
# Training loss (for one batch) at step 0: 0.02629738114774227
# Training loss (for one batch) at step 100: 0.02529587596654892
#
# Start of epoch 22
# Training loss (for one batch) at step 0: 0.02403433248400688
# Training loss (for one batch) at step 100: 0.02358030341565609
#
# Start of epoch 23
# Training loss (for one batch) at step 0: 0.02490498684346676
# Training loss (for one batch) at step 100: 0.02357654459774494
#
# Start of epoch 24
# Training loss (for one batch) at step 0: 0.022150980308651924
# Training loss (for one batch) at step 100: 0.0263375174254179
#
# Start of epoch 25
# Training loss (for one batch) at step 0: 0.02329408936202526
# Training loss (for one batch) at step 100: 0.023767853155732155
#
# Start of epoch 26
# Training loss (for one batch) at step 0: 0.02324339561164379
# Training loss (for one batch) at step 100: 0.022968195378780365
#
# Start of epoch 27
# Training loss (for one batch) at step 0: 0.021891262382268906
# Training loss (for one batch) at step 100: 0.022156845778226852
#
# Start of epoch 28
# Training loss (for one batch) at step 0: 0.02330932207405567
# Training loss (for one batch) at step 100: 0.02371278777718544
#
# Start of epoch 29
# Training loss (for one batch) at step 0: 0.022856496274471283
# Training loss (for one batch) at step 100: 0.02227257937192917
#
# Start of epoch 30
# Training loss (for one batch) at step 0: 0.022194653749465942
# Training loss (for one batch) at step 100: 0.022220885381102562
#
# Start of epoch 31
# Training loss (for one batch) at step 0: 0.021005623042583466
# Training loss (for one batch) at step 100: 0.020961208269000053
#
# Start of epoch 32
# Training loss (for one batch) at step 0: 0.020384302362799644
# Training loss (for one batch) at step 100: 0.02202685736119747
#
# Start of epoch 33
# Training loss (for one batch) at step 0: 0.02217959426343441
# Training loss (for one batch) at step 100: 0.022221967577934265
#
# Start of epoch 34
# Training loss (for one batch) at step 0: 0.021347839385271072
# Training loss (for one batch) at step 100: 0.021609071642160416
#
# Start of epoch 35
# Training loss (for one batch) at step 0: 0.02288106642663479
# Training loss (for one batch) at step 100: 0.021019738167524338
#
# Start of epoch 36
# Training loss (for one batch) at step 0: 0.022875405848026276
# Training loss (for one batch) at step 100: 0.021595746278762817
#
# Start of epoch 37
# Training loss (for one batch) at step 0: 0.020669635385274887
# Training loss (for one batch) at step 100: 0.02227495238184929
#
# Start of epoch 38
# Training loss (for one batch) at step 0: 0.02054056152701378
# Training loss (for one batch) at step 100: 0.021215494722127914
#
# Start of epoch 39
# Training loss (for one batch) at step 0: 0.02007860131561756
# Training loss (for one batch) at step 100: 0.021864239126443863
#
# Start of epoch 40
# Training loss (for one batch) at step 0: 0.02154497802257538
# Training loss (for one batch) at step 100: 0.020142823457717896
#
# Start of epoch 41
# Training loss (for one batch) at step 0: 0.0209711492061615
# Training loss (for one batch) at step 100: 0.020713787525892258
#
# Start of epoch 42
# Training loss (for one batch) at step 0: 0.020384667441248894
# Training loss (for one batch) at step 100: 0.02039405331015587
#
# Start of epoch 43
# Training loss (for one batch) at step 0: 0.020141318440437317
# Training loss (for one batch) at step 100: 0.01960556022822857
#
# Start of epoch 44
# Training loss (for one batch) at step 0: 0.020728256553411484
# Training loss (for one batch) at step 100: 0.019898638129234314
#
# Start of epoch 45
# Training loss (for one batch) at step 0: 0.02004837617278099
# Training loss (for one batch) at step 100: 0.020771481096744537
#
# Start of epoch 46
# Training loss (for one batch) at step 0: 0.019946634769439697
# Training loss (for one batch) at step 100: 0.019579559564590454
#
# Start of epoch 47
# Training loss (for one batch) at step 0: 0.02045944146811962
# Training loss (for one batch) at step 100: 0.02040955051779747
#
# Start of epoch 48
# Training loss (for one batch) at step 0: 0.019555356353521347
# Training loss (for one batch) at step 100: 0.019640836864709854
#
# Start of epoch 49
# Training loss (for one batch) at step 0: 0.020201895385980606
# Training loss (for one batch) at step 100: 0.01898779347538948
#
# Start of epoch 50
# Training loss (for one batch) at step 0: 0.019335446879267693
# Training loss (for one batch) at step 100: 0.019947364926338196
#
# Start of epoch 51
# Training loss (for one batch) at step 0: 0.019067473709583282
# Training loss (for one batch) at step 100: 0.019394267350435257
#
# Start of epoch 52
# Training loss (for one batch) at step 0: 0.019179604947566986
# Training loss (for one batch) at step 100: 0.01936841942369938
#
# Start of epoch 53
# Training loss (for one batch) at step 0: 0.019929006695747375
# Training loss (for one batch) at step 100: 0.019722241908311844
#
# Start of epoch 54
# Training loss (for one batch) at step 0: 0.0193159356713295
# Training loss (for one batch) at step 100: 0.019373277202248573
#
# Start of epoch 55
# Training loss (for one batch) at step 0: 0.019111428409814835
# Training loss (for one batch) at step 100: 0.019101355224847794
#
# Start of epoch 56
# Training loss (for one batch) at step 0: 0.019564921036362648
# Training loss (for one batch) at step 100: 0.019608397036790848
#
# Start of epoch 57
# Training loss (for one batch) at step 0: 0.01975792832672596
# Training loss (for one batch) at step 100: 0.01982346549630165
#
# Start of epoch 58
# Training loss (for one batch) at step 0: 0.019886311143636703
# Training loss (for one batch) at step 100: 0.019258743152022362
#
# Start of epoch 59
# Training loss (for one batch) at step 0: 0.018858129158616066
# Training loss (for one batch) at step 100: 0.018646642565727234
#
# Start of epoch 60
# Training loss (for one batch) at step 0: 0.01968076266348362
# Training loss (for one batch) at step 100: 0.019159335643053055
#
# Start of epoch 61
# Training loss (for one batch) at step 0: 0.018605247139930725
# Training loss (for one batch) at step 100: 0.018837593495845795
#
# Start of epoch 62
# Training loss (for one batch) at step 0: 0.018458619713783264
# Training loss (for one batch) at step 100: 0.01863156259059906
#
# Start of epoch 63
# Training loss (for one batch) at step 0: 0.01896149106323719
# Training loss (for one batch) at step 100: 0.01853613182902336
#
# Start of epoch 64
# Training loss (for one batch) at step 0: 0.018874425441026688
# Training loss (for one batch) at step 100: 0.01943022385239601
#
# Start of epoch 65
# Training loss (for one batch) at step 0: 0.01885424740612507
# Training loss (for one batch) at step 100: 0.01939457468688488
#
# Start of epoch 66
# Training loss (for one batch) at step 0: 0.01876455545425415
# Training loss (for one batch) at step 100: 0.018767330795526505
#
# Start of epoch 67
# Training loss (for one batch) at step 0: 0.0186644084751606
# Training loss (for one batch) at step 100: 0.0192450899630785
#
# Start of epoch 68
# Training loss (for one batch) at step 0: 0.018664168193936348
# Training loss (for one batch) at step 100: 0.018536671996116638
#
# Start of epoch 69
# Training loss (for one batch) at step 0: 0.018564065918326378
# Training loss (for one batch) at step 100: 0.01885533705353737
#
# Start of epoch 70
# Training loss (for one batch) at step 0: 0.018647033721208572
# Training loss (for one batch) at step 100: 0.0195174477994442
#
# Start of epoch 71
# Training loss (for one batch) at step 0: 0.019382106140255928
# Training loss (for one batch) at step 100: 0.018121782690286636
#
# Start of epoch 72
# Training loss (for one batch) at step 0: 0.01929687149822712
# Training loss (for one batch) at step 100: 0.018099024891853333
#
# Start of epoch 73
# Training loss (for one batch) at step 0: 0.018231626600027084
# Training loss (for one batch) at step 100: 0.0188908688724041
#
# Start of epoch 74
# Training loss (for one batch) at step 0: 0.018715668469667435
# Training loss (for one batch) at step 100: 0.01852463372051716
#
# Start of epoch 75
# Training loss (for one batch) at step 0: 0.0186905600130558
# Training loss (for one batch) at step 100: 0.018318070098757744
#
# Start of epoch 76
# Training loss (for one batch) at step 0: 0.018625464290380478
# Training loss (for one batch) at step 100: 0.019022442400455475
#
# Start of epoch 77
# Training loss (for one batch) at step 0: 0.018327245488762856
# Training loss (for one batch) at step 100: 0.018401529639959335
#
# Start of epoch 78
# Training loss (for one batch) at step 0: 0.018860040232539177
# Training loss (for one batch) at step 100: 0.018568776547908783
#
# Start of epoch 79
# Training loss (for one batch) at step 0: 0.018433719873428345
# Training loss (for one batch) at step 100: 0.018559370189905167
#
# Start of epoch 80
# Training loss (for one batch) at step 0: 0.018719719722867012
# Training loss (for one batch) at step 100: 0.018696792423725128
#
# Start of epoch 81
# Training loss (for one batch) at step 0: 0.018201738595962524
# Training loss (for one batch) at step 100: 0.017970126122236252
#
# Start of epoch 82
# Training loss (for one batch) at step 0: 0.018113888800144196
# Training loss (for one batch) at step 100: 0.01803704909980297
#
# Start of epoch 83
# Training loss (for one batch) at step 0: 0.0184191782027483
# Training loss (for one batch) at step 100: 0.018290109932422638
#
# Start of epoch 84
# Training loss (for one batch) at step 0: 0.018387870863080025
# Training loss (for one batch) at step 100: 0.018642263486981392
#
# Start of epoch 85
# Training loss (for one batch) at step 0: 0.018112024292349815
# Training loss (for one batch) at step 100: 0.01865631528198719
#
# Start of epoch 86
# Training loss (for one batch) at step 0: 0.018500231206417084
# Training loss (for one batch) at step 100: 0.017860744148492813
#
# Start of epoch 87
# Training loss (for one batch) at step 0: 0.018146034330129623
# Training loss (for one batch) at step 100: 0.017939016222953796
#
# Start of epoch 88
# Training loss (for one batch) at step 0: 0.01810722053050995
# Training loss (for one batch) at step 100: 0.018804021179676056
#
# Start of epoch 89
# Training loss (for one batch) at step 0: 0.018144480884075165
# Training loss (for one batch) at step 100: 0.01854044757783413
#
# Start of epoch 90
# Training loss (for one batch) at step 0: 0.01808493211865425
# Training loss (for one batch) at step 100: 0.01807602308690548
#
# Start of epoch 91
# Training loss (for one batch) at step 0: 0.018273543566465378
# Training loss (for one batch) at step 100: 0.018302764743566513
#
# Start of epoch 92
# Training loss (for one batch) at step 0: 0.018180781975388527
# Training loss (for one batch) at step 100: 0.017983051016926765
#
# Start of epoch 93
# Training loss (for one batch) at step 0: 0.018163586035370827
# Training loss (for one batch) at step 100: 0.01838020235300064
#
# Start of epoch 94
# Training loss (for one batch) at step 0: 0.017903145402669907
# Training loss (for one batch) at step 100: 0.01819514110684395
#
# Start of epoch 95
# Training loss (for one batch) at step 0: 0.01812851056456566
# Training loss (for one batch) at step 100: 0.01783471554517746
#
# Start of epoch 96
# Training loss (for one batch) at step 0: 0.01842094399034977
# Training loss (for one batch) at step 100: 0.01824832893908024
#
# Start of epoch 97
# Training loss (for one batch) at step 0: 0.018489927053451538
# Training loss (for one batch) at step 100: 0.018231544643640518
#
# Start of epoch 98
# Training loss (for one batch) at step 0: 0.017923250794410706
# Training loss (for one batch) at step 100: 0.018085597082972527
#
# Start of epoch 99
# Training loss (for one batch) at step 0: 0.01842431165277958
# Training loss (for one batch) at step 100: 0.018287254497408867
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# /usr/local/lib/python3.13/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %% [markdown]
# It loaded CIFAR-10 and normalizing pixels to [0,1], batch at 256.
# - Data_augmentation (random crop, flip, zoom) inlucded inside the encoder -- every forward pass sees a randomly perturbed view
# - The create_encoder() mapped a 32x32x3 image to a 128-d embedding through 3 conv+pool blocks
# - The create_projection_head() added a 2-layer MLP (128 to 256 to 128) on top
# - It was trained with the head, then discard it and use the encoder output downstream
# - The training looped encodes each batch, projects it, L2-normalizes, builds a full
# - After 100 epochs, extract embeddings from the encoder and run t-SNE
#
# Results:
# - The loss rate dropped fast and flattened near 0.018
# - The t-SNE plot shows all ten CIFAR classes mixed together with no visible clusters
