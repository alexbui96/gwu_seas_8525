# %%
import torch
print(torch.cuda.get_device_name(0))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_10002/3938375799.py in <cell line: 0>()
#       1 import torch
# ----> 2 print(torch.cuda.get_device_name(0))
#
# /usr/local/lib/python3.13/dist-packages/torch/cuda/__init__.py in get_device_name(device)
#     651         str: the name of the device
#     652     """
# --> 653     return get_device_properties(device).name
#     654
#     655
#
# /usr/local/lib/python3.13/dist-packages/torch/cuda/__init__.py in get_device_properties(device)
#     684         _CudaDeviceProperties: the properties of the device
#     685     """
# --> 686     _lazy_init()  # will define _get_device_properties
#     687     device = _get_device_index(device, optional=True)
#     688     if device < 0 or device >= device_count():
#
# /usr/local/lib/python3.13/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     469             )
# ...

# %%
# !nvidia-smi
